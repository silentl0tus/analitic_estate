# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("_data.csv")

# %%
df.head()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID  объявления', 'Количество комнат', 'Тип', 'Метро',
#        'Адрес', 'Площадь, м2', 'Дом', 'Парковка', 'Цена', 'Телефоны',
#        'Описание', 'Ремонт', 'Площадь комнат, м2', 'Балкон', 'Окна', 'Санузел',
#        'Можно с детьми/животными', 'Дополнительно', 'Название ЖК',
#        'Серия дома', 'Высота потолков, м', 'Лифт', 'Мусоропровод',
#        'Ссылка на объявление'],
#       dtype='object')

# %%
df.drop(columns = ["Серия дома", "Название ЖК", "Парковка"], inplace=True) #Удалем колонки с наибольшим количеством пропусков

# %%
df.head(5)
# Out:
#    Unnamed: 0  ID  объявления Количество комнат       Тип  \
# 0           0       271271157                 4  Квартира
# 1           1       271634126                 4  Квартира
# 2           2       271173086   4, Оба варианта  Квартира
# 3           3       272197456   4, Оба варианта  Квартира
# 4           4       273614615                 2  Квартира
#
#                           Метро                             Адрес  \
# 0  м. Смоленская (9 мин пешком)     Москва, улица Новый Арбат, 27
# 1  м. Смоленская (8 мин пешком)     Москва, улица Новый Арбат, 27
# 2  м. Смоленская (7 мин пешком)     Москва, улица Новый Арбат, 27
# 3  м. Смоленская (3 мин пешком)  Москва, переулок Плотников, 21С1
# 4   м. Арбатская (7 мин пешком)     Москва, улица Новый Арбат, 15
#
#        Площадь, м2                        Дом  \
# 0       200.0/20.0           5/16, Монолитный
# 1  198.0/95.0/18.0  5/16, Монолитно-кирпичный
# 2  200.0/116.0/4.0                       5/16
# ...

# %%
df["Тип"].unique()
# Out:
# array(['Квартира'], dtype=object)

# %%
df.drop(columns = ["Тип"], inplace=True) #Удалем колонку т.к 1 уникальное знаечние

# %%
df.head()
# Out:
#    Unnamed: 0  ID  объявления Количество комнат                         Метро  \
# 0           0       271271157                 4  м. Смоленская (9 мин пешком)
# 1           1       271634126                 4  м. Смоленская (8 мин пешком)
# 2           2       271173086   4, Оба варианта  м. Смоленская (7 мин пешком)
# 3           3       272197456   4, Оба варианта  м. Смоленская (3 мин пешком)
# 4           4       273614615                 2   м. Арбатская (7 мин пешком)
#
#                               Адрес      Площадь, м2  \
# 0     Москва, улица Новый Арбат, 27       200.0/20.0
# 1     Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2     Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3  Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4     Москва, улица Новый Арбат, 15    58.0/38.0/5.0
#
#                          Дом  \
# 0           5/16, Монолитный
# 1  5/16, Монолитно-кирпичный
# 2                       5/16
# 3                        5/6
# ...

# %%
df.drop(columns = ["Телефоны"], inplace=True) # Удаляем колонку т.к не будет вляить на цену недвижимости

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23368 entries, 0 to 23367
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                23368 non-null  int64
#  1   ID  объявления            23368 non-null  int64
#  2   Количество комнат         22327 non-null  object
#  3   Метро                     22053 non-null  object
#  4   Адрес                     23368 non-null  object
#  5   Площадь, м2               23368 non-null  object
#  6   Дом                       23368 non-null  object
#  7   Цена                      23368 non-null  object
#  8   Описание                  23368 non-null  object
#  9   Ремонт                    20613 non-null  object
#  10  Площадь комнат, м2        14458 non-null  object
#  11  Балкон                    15390 non-null  object
#  12  Окна                      16755 non-null  object
# ...

# %%
df["Количество комнат"].unique() # Пытаюсь понять какие значения есть в колонке
# Out:
# array(['4', '4, Оба варианта', '2', '3', '5, Оба варианта',
#        '3, Изолированная', '5', '5, Изолированная', '2, Оба варианта',
#        '3, Оба варианта', '6', '1', '4, Изолированная', '6, Оба варианта',
#        '2, Изолированная', nan, '2, Смежная', '4, Смежная', '3, Смежная',
#        '6, Изолированная', '1, Изолированная', '1, Оба варианта',
#        '5, Смежная', '6, Смежная', '1, Смежная'], dtype=object)
